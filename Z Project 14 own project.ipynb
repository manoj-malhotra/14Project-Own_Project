# %%
import os
import numpy as np 
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from openpyxl import load_workbook
from pandas import *
from decimal import *

# %%
# path = "E:\\Personal\\ACADGILD\\Project"
# os.chdir(path)
# os.getcwd() 

# df = pd.read_excel("AZCMG_WF_All_Entities_Consolidated.xlsx", sheet_name = "BaseData")
# #df7 = pd.read_excel("A_df7_Sap_PO_Val_WF.xlsx", sheet_name="Sheet1")

# df.to_excel("E:\\Personal\\ACADGILD\\Project\\AZCMG_WF_All_Entities_Consolidated_Upload.xlsx", sheet_name="BaseData")
# #df7.to_excel("E:\\Personal\\ACADGILD\\Project\\A1_Input_File\\A_df7_Sap_PO_Val_WF.xlsx", sheet_name="Sheet1")

# print('Completed')
# Out:
# Completed

# %%
path = "E:\\CMG_Feb'19"
os.chdir(path)
os.getcwd() 

df = pd.read_excel("AYCMG_WF_All_Entities_Consolidated_For_Uploading.xlsx", sheet_name="BaseData")
df2 = pd.read_excel("A_CMG-Support.xlsx", sheet_name="Emp")
df3 = pd.read_excel("A_CMG-Support.xlsx", sheet_name="CCFun")
df4 = pd.read_excel("A_CMG-Support.xlsx", sheet_name="PG")
df5 = pd.read_excel("A_CMG-Support.xlsx", sheet_name="Plant")
df6 = pd.read_excel("A_CMG-Support.xlsx", sheet_name="ApproverCat")
df8 = pd.read_excel("A_CMG-Support.xlsx", sheet_name="WF_Entity")
df7 = pd.read_excel("A_CMG-Support.xlsx", sheet_name="SAP_PO_Val")
Saving = pd.read_excel("A_CMG-Support.xlsx", sheet_name="SavingData")
CAT_Anly_Partner = pd.read_excel("A_CMG-Support.xlsx", sheet_name="CAT_Partner")
CAT_Anly_POR = pd.read_excel("A_CMG-Support.xlsx", sheet_name="CAT_POR")

df.replace(np.nan, 0, inplace=True)

#df.to_excel("E:\\CMG_Feb'19\\AYCMG_WF_All_Entities_Consolidated_For_Uploading.xlsx", sheet_name="BaseData")
print('Completed')
df.head()
# Out:
# Completed
#    S.No.  CompanyCode RequestType                 RIBName  RIBEmpID  \
# 0      1         1000     SERVICE  Bhoopal Reddy Golkonda  10100343
# 1      2         1000     SERVICE  Bhoopal Reddy Golkonda  10100343
# 2      3         1000     SERVICE     Uttam Kumar Sunkari  10103949
# 3      4         1000        BOTH         Abhishek Gaurav  10104922
# 4      5         1000     SERVICE        Prabhakar  Rao K  10101317
#
#              RIBCostCenterName                 RIFName  Costcenter  \
# 0   Zee Telugu_Production Dept                       0  10022H0107
# 1   Zee Telugu_Production Dept  Bhoopal Reddy Golkonda  10022H0107
# 2   Zee Telugu_Production Dept                       0  10022H0107
# 3                Z5X_Common CC                       0  10071M0106
# 4  Zee Kannada_Production Dept           ANTONY DASS B  10023B0108
#
#   ParentURValue    URIntroductionDate       ...         \
# 0    393,000.00  12/Jul/2018 15:58:10       ...
# ...

# %%
    df["CompanyCode"] = df["CompanyCode"].astype(str)
    df8["CompanyCode_WF"] = df8["CompanyCode_WF"].astype(str)      
    df = pd.merge(df, df8, left_on = 'CompanyCode', right_on='CompanyCode_WF')

    #Segregating STO and Procurement
    for a in range(len(df)):
        if df.loc[a,"RequestType"] == "STOCKTRANSFER":
            df.loc[a,"TransactionType"] = "STO"
        elif df.loc[a,"PurchaseGroup"] == "602#STO":
            df.loc[a,"TransactionType"] = "STO"
        elif df.loc[a,"PurchaseGroup"] == "717#STO":
            df.loc[a,"TransactionType"] = "STO"
        else:
            df.loc[a,"TransactionType"] = "Procurement"

    #Segregating work exit cases
    for b in range(len(df)):
        if df.loc[b,"CurrentStage"] == "Work Exit1":
            df.loc[b,"TransactionStage"]="Work Exit1"
        elif df.loc[b,"CurrentStage"] == "Approve_Sec":
            df.loc[b,"TransactionStage"]="Work Exit1"
        elif df.loc[b,"CurrentStage"] == "PO_Verification":
            df.loc[b,"TransactionStage"]="Work Exit1"
        elif df.loc[b,"CurrentStage"] == "Hold_PO_Release":
            df.loc[b,"TransactionStage"]="Work Exit1"
        elif df.loc[b,"CurrentStage"] == "Approve_Entity_Finance":
            df.loc[b,"TransactionStage"]="Work Exit1"
        else:
            df.loc[b,"TransactionStage"] = "WIP"

    #subset list of employees with category A
    #Cat_emp_list=df.loc[df["Category"] == "A",["Buyer"]]
    #Buyer=[80000037,80000051,80000055,80000172,80000222,80000269,80000270,80000272,80000275,80000276,80000282,80000283,80000297,80000304,80000361,80000362,80000363,80000531,80000533,80000534,80000590,80000591,80000596,80000599,80000610,80000611,80000642,80000645,88000073,80000008,80000016,80000036,80000053,80000164,80000224,80000404
    #]
    #Approver=[80000037,80000051,80000055,80000172,80000222,80000269,80000270,80000272,80000275,80000276,80000282,80000283,80000297,80000304,80000361,80000362,80000363,80000531,80000533,80000534,80000590,80000591,80000596,80000599,80000610,80000611,80000642,80000645,88000073,80000008,80000016,80000036,80000053,80000164,80000224,80000404
    #]
    #Legal=[80000279,80000585]
    #Travel=[80000407]
    #Import=[80000485]
    #Admin=[80000001,80000612]

    #creating category for buyer
    #df["Category_1"]=np.where(df["FinalVendorSelectedBy"].astype(str).str.startswith("8"),"EBEX Other","Entity Buyer")
    #df["Buyer-EBEX-Entity"]=np.where(df["FinalVendorSelectedBy"].isin(Buyer),"EBEX Buyer",df["Category_1"])
    #df["Buyer-EBEX-Entity"].value_counts()

    #print(df["Category_2"].value_counts())
    #print("Procurement handle INR",np.sum(df["POExclTax"]))
    #creating category for approver
    #df["Category_3"]=np.where(df["FinalVendorApprovedBy"].astype(str).str.startswith("8"),"EBEX Other","Entity Procurement")
    #df["Category_4"]=np.where(df["FinalVendorApprovedBy"].isin(Approver),"EBEX Commercial Approver",df["Category_3"])
    #df["Category_5"]=np.where(df["FinalVendorApprovedBy"].isin(Legal),"EBEX Legal",df["Category_4"])
    #df["Category_6"]=np.where(df["FinalVendorApprovedBy"].isin(Travel),"EBEX Travel",df["Category_5"])
    #df["Category_7"]=np.where(df["FinalVendorApprovedBy"].isin(Import),"EBEX Import",df["Category_6"])
    #df["Category_8"]=np.where(df["FinalVendorApprovedBy"].isin(Admin),"EBEX Admin",df["Category_7"])
    #df["Category_8"].value_counts()

    #df.drop(["Category_3","Category_4","Category_5","Category_6","Category_7"],axis = 1, inplace = True)
    #df["Category_8"]
    #print(df["Category_8"].value_counts())
    #print("Procurement handle INR",np.sum(df["POExclTax"]))

    #converting into STR object to capture commercialapprover thru #Extrcting first three letters from PurchaseGroup

    df["FinalVendorSelectedBy"] = df["FinalVendorSelectedBy"].astype(str)
    df["FinalVendorApprovedBy"] = df["FinalVendorApprovedBy"].astype(str)
    df2["FinalVendorSelectedBy"] = df2["FinalVendorSelectedBy"].astype(str)
    df["PlantCode"] = df["PlantCode"].astype(str)
    df5["Plant"] = df5["Plant"].astype(str)
    df6["FinalVendorApprovedByCode"] = df6["FinalVendorApprovedByCode"].astype(str)

    #to apply on all rows of column use apply lambda fnction
    df["PG"] = df["PurchaseGroup"].astype(str).apply(lambda x: x[:3])
    df["PG"] = df["PG"].astype(str)
    df4["PGW"] = df4["PGW"].astype(str)

    # Mergng dataframes 
    #df = pd.merge(df, df3[["RIBCostCenterName","Function"]], left_on = 'RIBCostCenterName', right_on='RIBCostCenterName')==> to get defined column with keys
    df = pd.merge(df, df2, left_on = "FinalVendorSelectedBy", right_on="FinalVendorSelectedBy")
    df = pd.merge(df, df3, left_on = "RIBCostCenterName", right_on="RIBCostCenterName")
    df = pd.merge(df, df5, left_on = "PlantCode", right_on='Plant')
    df = pd.merge(df, df6, left_on = "FinalVendorApprovedBy", right_on="FinalVendorApprovedByCode")
    df = pd.merge(df, df4, left_on = 'PG', right_on='PGW')

    #Part A==> Categorisation of EBEX Vs Entity Procurement from "ApproverCat"
    #Part B ==> EC Code ==> Commercial Closed & Post Facto
    #Part C ==> PostFactoReq==> if B commercial closed cases having post facto decision "YES" then taken as post facto to arrive at commercial closed cases
    #Part D==> PostFactoReq==> if B commerci

    #Part==>A ==> Post facto are covered in C and then remaining in Part-D ==> Buyer Entity and approver = EBEX commercial
    df["ApproverCat"] = df["ApproverCat"].astype(str)

    for e in range(len(df)):
        if df.loc[e,"ApproverCat"] == "Entity Procurement":
            df.loc[e,"ProcurementNegotiatedBy"] = "Entity"
        else:
            df.loc[e,"ProcurementNegotiatedBy"] = "EBEX"
    print('Completed')
# Out:
# Completed

# %%
#If filling blank with 0 and then with EC-00
#df["TypeofProcurment"].fillna(0,axis =1, inplace = True)
#Part-B==> getting numeric values from EC-02-TECHNICALLY RECOMMENDED OR AUTHORIZED REPAIR VENDOR
df["TypeofProcurment"].replace(0, "EC-00",inplace = True)
#df = df["EcCode"].fillna(0,axis =1)
df["EcCode"] = df["TypeofProcurment"].astype("str").apply(lambda x:x.split("-")[0:2])
#df["EcCode"]
cc=["00","01","02","03","04","08","09","13","16"]
pf=["05","06","07","10","11","12","14","15","17","18","19"]
for c in range(len(df)):
    if df["EcCode"][c][1] in (cc):
        df.loc[c,"EcCodeProcurementCategory"]="Commercial Closed"
    else:
        df.loc[c,"EcCodeProcurementCategory"]="Post Facto"
        
#Part-C==> Filling PostFactoReq blank cases with zero and replacing with NA 
#df["PostFactoReq"].fillna(0, inplace = True)
df["PostFactoReq"].replace(0, "NA",inplace = True)
#Segregating Commercial closed cases from Post Facto column having user decision and EC codes descision
for d in range(len(df)):
    if (df.loc[d,"PostFactoReq"] == "YES"):
        df.loc[d,"EcCodeProcurementCategory"]="Post Facto"
    elif df.loc[d,"EcCodeProcurementCategory"] == "Post Facto":
        df.loc[d,"EcCodeProcurementCategory"]="Post Facto"     
    elif (df.loc[d,"ProcurementNegotiatedBy"] == "EBEX") and (df.loc[d,"BuyerCategoryM"] == "Entity"):
        df.loc[d,"EcCodeProcurementCategory"]="Post Facto"  
    elif (df.loc[d,"ProcurementNegotiatedBy"] == "Entity") and (df.loc[d,"BuyerCategoryM"] == "Entity"):
        df.loc[d,"EcCodeProcurementCategory"]="Commercial Closed"  
    else:
        df.loc[d,"EcCodeProcurementCategory"]="Commercial Closed"

#TAT calculation for productivity Analysis
#If the column has nan values it is giving na values
#fill missing value for the dataframe
#df = df.fillna(0,axis =1, inplace = True)
#df["VendorSearch(TAT)"].fillna(0,axis =1, inplace = True)
#df["VendorSelection(TAT)"].fillna(0,axis =1, inplace = True)
#df["VendorApprove(TAT)"].fillna(0,axis =1, inplace = True)
#df["Generate_PO(TAT)"].fillna(0,axis =1, inplace = True)
# I have repalced nan with 0 for the entire dataframe ,based on the column logic you can repalce column wise  missing values with mean,median etc
df["TAT Days1"] = df["VendorSearch(TAT)"]+df["VendorSelection(TAT)"]+df["VendorApprove(TAT)"]+df["Generate_PO(TAT)"]
df["TAT Days2"] = df["TAT Days1"] / (60*9)
df["TAT Days"]=df["TAT Days2"].round(0).astype(int)
#df["TAT Days"]

#Categorisation of purchase into Fresh, repeat and Projects
#Filling CaseType blank cases with zero and replacing with NA 
#df["CaseType"].fillna(0, inplace = True)
df["CaseType"].replace(0, "NA",inplace = True)
for a in range(len(df)):
    if df.loc[a,"CaseType"] == "FRESH CASE":
        df.loc[a,"PurFresh/Repeat"] = "FRESH"
    elif df.loc[a,"CaseType"] == "TECHNO COMMERCIAL":
        df.loc[a,"PurFresh/Repeat"] = "FRESH"
    elif df.loc[a,"CaseType"] == "NA":
        df.loc[a,"PurFresh/Repeat"] = "FRESH"
    elif df.loc[a,"CaseType"] == "PROJECTS":
        df.loc[a,"PurFresh/Repeat"] = "PROJECTS"
    else:
        df.loc[a,"PurFresh/Repeat"] = "REPEAT"
        
#TAT Classification basis of PurFresh/Repeat
#df["TAT MMM"] = np.where(((df["TAT Days"] <= 5) & (df["PurFresh/Repeat"] == "REPEAT")) & ((df["TAT Days"] <= 15) & (df["PurFresh/Repeat"] == "FRESH")) & ((df["TAT Days"] <= 30) & (df["PurFresh/Repeat"] == "PROJECTS")), "With In TAT", "Out In TAT")
for i in range(len(df)):
    if (df.loc[i,"TAT Days"] <=5) and (df.loc[i,"PurFresh/Repeat"] == "REPEAT"):
        df.loc[i,"TATCalculation"] = "With In TAT"
    elif (df.loc[i,"TAT Days"] <=15) and (df.loc[i,"PurFresh/Repeat"] == "FRESH"):
        df.loc[i,"TATCalculation"] = "With In TAT"
    elif (df.loc[i,"TAT Days"] <=30) and (df.loc[i,"PurFresh/Repeat"] == "PROJECTS"):
        df.loc[i,"TATCalculation"] = "With In TAT"
    else:
        df.loc[i,"TATCalculation"] = "Out In TAT"

#defining Function basis purchase groups under head PGFunM. where ever function is CC Function then taken function from FunctionCC else remain same
df['PGFunM'] = np.where(df['PGFunM'] == "CC Function", df['FunctionCC'], df['PGFunM'])
df['PGFunM'] = np.where(df['PGFunM'] == "Zmissing", df['FunctionCC'], df['PGFunM'])

#Dropping of STO by converting into NAN values
df['TransactionType'].replace('STO', np.nan, inplace=True)
df.dropna(subset=['TransactionType'], inplace=True)

df=df.rename(columns = {'PONo':'PO_Number_WF'})
df["PO_Number_WF"] = df["PO_Number_WF"].astype(str)
df7["PO Number"] = df7["PO Number"].astype(str)

#Indexing of column name
columnsTitles = ["S.No.","CompanyCode","CompanyCode_WF","CompanyCode_Desc_WF","Entity_WF","RequestType","TransactionType","PurchaseGroup","PG","PGW","GRP Desc","PGFun","PGFunM","Entity","Plant","PlantEntityName","PlantCode","PlantCodeDescription","RIBName","RIBEmpID","RIBCostCenterName","FunctionSubCC","FunctionCC","TransactionStage","CurrentStage","PurposeOFRequest","PO_Number_WF","Wi_name","FinalPOCreationDate","FinalPOApprovalDate","RIFName","Costcenter","ParentURValue","URIntroductionDate","FinalApprovalDate","PRNO","FinalPRApprovalDate","PendingSince","FinalVendorSearchedBy","PR_CATEGORY(TAT)","PR_APPROVE(TAT)","Create_PR(TAT)","UR_Approval_TAT","VendorSearch(TAT)","VendorSelection(TAT)","VendorApprove(TAT)","Generate_PO(TAT)","TAT Days1","TAT Days2","TAT Days","CaseType","PurFresh/Repeat","TATCalculation","PO_Approve_Entity/Approve_SEC(TAT)","FinalVendorName","VendorCodeoffinalisedvendor","VendorSearchCompletionTime","VendorSelectedCompletionTime","VendorApprovalCompletionTime","Currency","POExclTax","POInclTax","PODeliveryAddress","PRCategory","POCategory","AccountAssignmentCategory","ProjectCode","ProjectCodeName","PendingSinceDate","PartialPoFlag","PersonlastAssign","PersonlastAssignName","ParentPocase","ParentWiname_VendorApprove","ParentWiname_PRCategory","CostCentreName","RIBCostCenter","WBS_Code","PO_Modification","FinalVendorSelectedBy","Employee_Name","EmpFunction-WF","Employment_Status","BuyerCategory","BuyerCategoryM","FinalVendorApprovedBy","FinalVendorApprovedByName","FinalVendorApprovedByCode","Employee_Name_Approver","ApproverCat","ProcurementNegotiatedBy","EcCodeProcurementCategory","PostFactoReq","TypeofProcurment","EcCode"]
M_WF = df.reindex(columns=columnsTitles)

M_WF.to_excel("E:\\CMG_Feb'19\\AS_CMG_Report_Before_SAP_PO_Value.xlsx")
print('Completed')
#Successfully implemented
# Out:
# Completed

# %%
# WF Data merging with SAP to get SAP PO Value_CMG_Report ==> before saving
M_WF_SAP = pd.merge(M_WF, df7, how='left', left_on = 'PO_Number_WF', right_on='PO Number')

M_WF_SAP["SAP_PO_Val_Basic(INR)_Mn"] = (M_WF_SAP["SAP_PO_Val_Basic.(INR)"])/1000000
decimals = 2    
M_WF_SAP["SAP_PO_Val_Basic(INR)_Mn"] = M_WF_SAP["SAP_PO_Val_Basic(INR)_Mn"].apply(lambda x: round(x, decimals))

#Creating year, month & date
M_WF_SAP["PO Document Date"] = M_WF_SAP["PO Document Date"].astype(str).apply(lambda x: x[:10])
M_WF_SAP["Year"] = M_WF_SAP["PO Document Date"].astype(str).apply(lambda x: x[:4])
M_WF_SAP["Month"] = M_WF_SAP["PO Document Date"].astype(str).apply(lambda x: x[5:7])
M_WF_SAP["Day"] = M_WF_SAP["PO Document Date"].astype(str).apply(lambda x: x[-2:])

#Dropping of PO's which are not in SAP but available in WF
M_WF_SAP['PO Number'].replace('', np.nan, inplace=True)
M_WF_SAP.dropna(subset=['PO Number'], inplace=True)

M_WF_SAP.to_excel("E:\\CMG_Feb'19\\AR_CMG_Report_After_SAP_PO_Value.xlsx")
print('Completed')
#Successfully implemented
# Out:
# Completed

# %%
#Merging of saving data with M_WF_SAP or AR_CMG_Report_After_SAP_PO_Value and saving evaluation (Actual and computed=>90% or 30%)
M_WF_SAP["PO Number"] = M_WF_SAP["PO Number"].astype(str)
Saving["PO_No_Saving"] = Saving["PO_No_Saving"].astype(str)
Saving["Initial_L1_Cost"] = Saving["Initial_L1_Cost"].astype(int)

M_WF_SAP_Saving = pd.merge(M_WF_SAP, Saving, how='left', left_on = 'PO Number', right_on='PO_No_Saving')

#Updating SAP PO No (No_Saving_Reported) and SAP PO Value wherever no saving has been declared
M_WF_SAP_Saving['PO_No_Saving'].replace(np.nan, 'No_Saving_Reported', inplace=True)

for d in range(len(M_WF_SAP_Saving)):
    if (M_WF_SAP_Saving.loc[d,"PO_No_Saving"] == "No_Saving_Reported"):
        M_WF_SAP_Saving.loc[d,"Initial_L1_Cost"] = M_WF_SAP_Saving.loc[d,"SAP_PO_Val_Basic.(INR)"]
    else:
        M_WF_SAP_Saving.loc[d,"Initial_L1_Cost"] = M_WF_SAP_Saving.loc[d,"Initial_L1_Cost"]

#Calculation of Buyers actual saving
M_WF_SAP_Saving["Initial_L1_Cost_Mn"] = (M_WF_SAP_Saving["Initial_L1_Cost"])/1000000
M_WF_SAP_Saving["Saving_Actual"] = (M_WF_SAP_Saving["Initial_L1_Cost"]-M_WF_SAP_Saving["SAP_PO_Val_Basic.(INR)"])
M_WF_SAP_Saving["Saving_Actual_Mn"] = (M_WF_SAP_Saving["Saving_Actual"])/1000000
decimals = 2
M_WF_SAP_Saving["Initial_L1_Cost_Mn"] = M_WF_SAP_Saving["Initial_L1_Cost_Mn"].apply(lambda x: round(x, decimals))
M_WF_SAP_Saving["Saving_Actual"] = M_WF_SAP_Saving["Saving_Actual"].apply(lambda x: round(x, decimals))
M_WF_SAP_Saving["Saving_Actual_Mn"] = M_WF_SAP_Saving["Saving_Actual_Mn"].apply(lambda x: round(x, decimals))

#Categorisation of saving declared and NIL saving cases
for i in range(len(M_WF_SAP_Saving)):
    if (M_WF_SAP_Saving.loc[i,"Saving_Actual"] > 0):
        M_WF_SAP_Saving.loc[i,"Saving_Status"] = "Saving Declared"
    else:
        M_WF_SAP_Saving.loc[i,"Saving_Status"] = "No_Saving_Reported"

#Computation of 30% saving where saving is > 30% and 90% saving where saving is 30% saving fot reorting to entity 
M_WF_SAP_Saving["Saving %_Actual"] = (M_WF_SAP_Saving["Saving_Actual"]/M_WF_SAP_Saving["Initial_L1_Cost"])*100
decimals = 2
M_WF_SAP_Saving["Saving %_Actual"] = M_WF_SAP_Saving["Saving %_Actual"].apply(lambda x: round(x, decimals))

for i in range(len(M_WF_SAP_Saving)):
    if (M_WF_SAP_Saving.loc[i,"Saving %_Actual"] <= 30):
        M_WF_SAP_Saving.loc[i,"CMG_Saving"] = (M_WF_SAP_Saving.loc[i,"Saving_Actual"]*.9)
    else:
        M_WF_SAP_Saving.loc[i,"CMG_Saving"] = (M_WF_SAP_Saving.loc[i,"Initial_L1_Cost"]*.3)

M_WF_SAP_Saving["CMG_Saving_Mn"] = (M_WF_SAP_Saving["CMG_Saving"])/1000000
decimals = 2
M_WF_SAP_Saving["CMG_Saving_Mn"] = M_WF_SAP_Saving["CMG_Saving_Mn"].apply(lambda x: round(x, decimals))

# Converting Month number intow words and Creating QTR Column
M_WF_SAP_Saving["Month"] = M_WF_SAP_Saving["Month"].astype(str)
for a in range(len(M_WF_SAP_Saving)):
    if M_WF_SAP_Saving.loc[a,"Month"] == "01":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Jan"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q4"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "02":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Feb"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q4"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "03":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Mar"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q4"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "04":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Apr"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q1"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "05":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "May"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q1"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "06":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Jun"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q1"        
    elif M_WF_SAP_Saving.loc[a,"Month"] == "07":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Jul"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q2"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "08":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Aug"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q2"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "09":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Sep"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q2"      
    elif M_WF_SAP_Saving.loc[a,"Month"] == "10":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Oct"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q3"
    elif M_WF_SAP_Saving.loc[a,"Month"] == "11":
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Nov"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q3"
    else:
        M_WF_SAP_Saving.loc[a,"Month_W"] = "Dec"
        M_WF_SAP_Saving.loc[a,"QTR"] = "Q3"

#Reading Partner and PurposeOFRequest based Category_Sub_Category from file name A_CMG-Support.xlsx
CAT_Anly_Partner = pd.read_excel("A_CMG-Support.xlsx", sheet_name="CAT_Partner")
CAT_Anly_POR = pd.read_excel("A_CMG-Support.xlsx", sheet_name="CAT_POR")

#Converting character into lower character of column PurposeOFRequest for Category_Sub_Category identification
M_WF_SAP_Saving['PurposeOFRequest'] = M_WF_SAP_Saving['PurposeOFRequest'].str.lower()
M_WF_SAP_Saving = M_WF_SAP_Saving.rename(columns = {'VendorCodeoffinalisedvendor':'Vendor_Code_WF'})

#creating category, sub categories basis words from PurposeOFRequest under head M_WF_SAP_Saving['SubCategory_POR'] and saving into file name A_CMG-Support
Category_Sub_Category = [" Disney Broadcasting "," Pay channel deal ","Disney Broadcasting ","Pay channel deal "," Disney Broadcasting"," Pay channel deal","Disney Broadcasting","Pay channel deal","link shifting"," link shifting","link shifting "," link shifting "," Salary "," Remuneration "," Bonus "," Gratuity "," reimbursement "," conveyance "," DRIVER "," REMUNERATION "," House rental "," Liberium "," Incentives "," salaries "," INCENTIVES "," Remunertion "," Remu
Point to point","P2P link","MBPS","gig","PRI","fibre cable","ug link","Radio Ad","Radio Ads","Radio Plan","Radio Campaign","Print Ad","Print Ads","Print Plan","Print Campaign","TV Ad","TV Ads","TV Plan","TV Campaign","Theatre Ad","Cable Ad","Cable Ads","cable Campaign","Trade Mailers","Publication expenses","public notice ad","public notice add","TV PLAN","press ad","Office Rent","rent office","Renewal of office","Office rent","OFFICE HIRING","HUB LOCATION RENTAL","floor hire charges","Insurance","GMC","Medical health","mediclaim","Car park","cab hire","vehice hire","cab servic","Bus Hire","Bus Serv","Taxi","OLA Cab","Vehicle Hire","UBER","car hire charges","car hire","cab hiring","UPS","Inverter","Battery","Batteries","FACILITY MANAGEMENT SERVICE","Housekeeping","House keeping","hosting charges","mac book","hosting on azure","laptops","macbook","promotional transactional sms","sms for promotional campaign","Dealer Meet","OOH","Outdoor","Hoarding","Branding","Launch Meeting","Press Conference","event","events","Prize Money","Gift","Merchandise","Content","Rent","Hire"]

def matcher(x):
    for i in Category_Sub_Category:
        if i.lower() in x.lower():
            return i
    else:
        return np.nan

M_WF_SAP_Saving['SubCategory_POR'] = M_WF_SAP_Saving['PurposeOFRequest'].apply(matcher)

#Removing right and lift spaces from sub category created basis PurposeOFRequest
M_WF_SAP_Saving['SubCategory_POR'] = M_WF_SAP_Saving['SubCategory_POR'].str.lstrip()
M_WF_SAP_Saving['SubCategory_POR'] = M_WF_SAP_Saving['SubCategory_POR'].str.rstrip()

#Merging partners based categories and PurposeOFRequest based categories with last file name M_WF_SAP_Saving to get main category and amenable status
M_WF_SAP_Saving_CAT_Partner = pd.merge(M_WF_SAP_Saving, CAT_Anly_Partner, how='left', left_on = 'Vendor_Code_WF', right_on='Vendor_Code_P')
M_WF_SAP_Saving_CAT_Partner_POR = pd.merge(M_WF_SAP_Saving_CAT_Partner, CAT_Anly_POR, how='left', left_on = 'SubCategory_POR', right_on='SubCategory_POR')


# #shifting category/sub category of partners to PurposeOFRequest
M_WF_SAP_Saving_CAT_Partner_POR["Amenable_Status_POR"] = M_WF_SAP_Saving_CAT_Partner_POR["Amenable_Status_POR"].astype(str)
M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'].replace('', np.nan, inplace=True)

M_WF_SAP_Saving_CAT_Partner_POR["Category_POR"] = M_WF_SAP_Saving_CAT_Partner_POR["Category_POR"].astype(str)
M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'].replace('', np.nan, inplace=True)

M_WF_SAP_Saving_CAT_Partner_POR["SubCategory_POR"] = M_WF_SAP_Saving_CAT_Partner_POR["SubCategory_POR"].astype(str)
M_WF_SAP_Saving_CAT_Partner_POR['SubCategory_POR'].replace('', np.nan, inplace=True)

M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'] == "nan", M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Sts_P'], M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'])
M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'] == "nan", M_WF_SAP_Saving_CAT_Partner_POR['Category_P'], M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'])
M_WF_SAP_Saving_CAT_Partner_POR['SubCategory_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['SubCategory_POR'] == "nan", M_WF_SAP_Saving_CAT_Partner_POR['Sub_Category_P'], M_WF_SAP_Saving_CAT_Partner_POR['SubCategory_POR'])

#Updating Non amendable in column Amenable_Status_POR if PurchaseGroup is having content
M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['PurchaseGroup'] == "601#Broadcasting and Content", "Non Amenable", M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'])
M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['PurchaseGroup'] == "601#Broadcasting and Content", "Content", M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'])

M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['PurchaseGroup'] == "704#Content", "Non Amenable", M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'])
M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['PurchaseGroup'] == "704#Content", "Content", M_WF_SAP_Saving_CAT_Partner_POR['Category_POR'])

#Saving cases are being declared as amenable which has been categorised under Non Amenable
M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'] = np.where(M_WF_SAP_Saving_CAT_Partner_POR['Saving_Status'] == "Saving Declared", "Amenable", M_WF_SAP_Saving_CAT_Partner_POR['Amenable_Status_POR'])

#Droping of useless columns
columns_drop = ["PG","Entity","RIFName","PendingSince","PODeliveryAddress","PRCategory","POCategory","AccountAssignmentCategory","ProjectCode","ProjectCodeName","PendingSinceDate","PartialPoFlag","PersonlastAssign","PersonlastAssignName","ParentPocase","ParentWiname_VendorApprove","ParentWiname_PRCategory","CostCentreName","RIBCostCenter","WBS_Code","PO_Modification"]
M_WF_SAP_Saving_CAT_Partner_POR.drop(columns_drop, axis=1, inplace=True)

#Indexing of column name
columnsTitles = ["S.No.","CompanyCode","CompanyCode_WF","CompanyCode_Desc_WF","Entity_WF","RequestType","TransactionType","PurchaseGroup","PGW","GRP Desc","PGFun","PGFunM","Plant","PlantEntityName","PlantCode","PlantCodeDescription","RIBName","RIBEmpID","RIBCostCenterName","FunctionSubCC","FunctionCC","TransactionStage","CurrentStage","PurposeOFRequest","PO_Number_WF","Wi_name","FinalPOCreationDate","FinalPOApprovalDate","Costcenter","ParentURValue","URIntroductionDate","FinalApprovalDate","PRNO","FinalPRApprovalDate","FinalVendorSearchedBy","PR_CATEGORY(TAT)","PR_APPROVE(TAT)","Create_PR(TAT)","UR_Approval_TAT","VendorSearch(TAT)","VendorSelection(TAT)","VendorApprove(TAT)","Generate_PO(TAT)","TAT Days1","TAT Days2","TAT Days","CaseType","PurFresh/Repeat","TATCalculation","PO_Approve_Entity/Approve_SEC(TAT)","FinalVendorName","Vendor_Code_WF","VendorSearchCompletionTime","VendorSelectedCompletionTime","VendorApprovalCompletionTime","Currency","POExclTax","POInclTax","FinalVendorSelectedBy","Employee_Name","EmpFunction-WF","Employment_Status","BuyerCategory","BuyerCategoryM","FinalVendorApprovedBy","FinalVendorApprovedByName","FinalVendorApprovedByCode","Employee_Name_Approver","ApproverCat","ProcurementNegotiatedBy","EcCodeProcurementCategory","PostFactoReq","TypeofProcurment","EcCode","PO Number","PO Document Date","Year","Month","Day","Month_W","QTR","SAP_PO_Val_Basic.(INR)","SAP_PO_Val_Basic(INR)_Mn","PO_No_Saving","Saving_Approved_Status","Last Purchase Order No","Initial_L1_Cost","Initial_L1_Cost_Mn","Saving_Actual","Saving_Actual_Mn","Saving_Status","Saving %_Actual","CMG_Saving","CMG_Saving_Mn","Vendor_Code_P","Category_P","Sub_Category_P","Amenable_Sts_P","Category_POR","SubCategory_POR","Amenable_Status_POR"]
Report = M_WF_SAP_Saving_CAT_Partner_POR.reindex(columns=columnsTitles)

#Filling un-searched cases with Amenable category 
Report['Amenable_Status_POR'].fillna('Amenable', inplace=True)
#Report["Amenable_Status_POR"][3538]

Report.to_excel("E:\\CMG_Feb'19\\AN_WF_SAP_Saving_Report.xlsx")
print('Completed')
# Out:
# Completed

# %%
# tab_tots = EBEX_Entity_Proc.groupby(level='ProcurementNegotiatedBy').sum()
# print(tab_tots)

# tab_tots1 = EBEX_Entity_Proc.groupby(level='EcCodeProcurementCategory').sum()
# tab_tots1.index = [tab_tots1.index, ['Total'] * len(tab_tots1)]
#    #tab_tots1 = pd.concat([EBEX_Entity_Proc, tab_tots]).sort_index().append(EBEX_Entity_Proc.sum().rename(('Grand', 'Total')))
# print(tab_tots1)

# EBEX_Entity_Proc_Value.loc[('Total')] = EBEX_Entity_Proc_Value.loc['Entity_WF'].sum()
# # EBEX_Entity_Proc_Value[('Total')] = EBEX_Entity_Proc['SAP_PO_Val_Basic(INR)_Mn'].sum()
# # # EBEX_Entity_Proc.loc[('Grand Total', ''),:] = EBEX_Entity_Proc.iloc[:(EBEX_Entity_Proc.shape[0]-1), :].sum()
# EBEX_Entity_Proc_Value

# %%
# #M_WF_SAP_Saving.head()
#M_WF_SAP_Saving["PO_No_Saving"][0:5]
# #M_WF_SAP_Saving['PO_No_Saving'].replace(np.nan, 'NIL', inplace=True)
# M_WF_SAP_Saving["PO_No_Saving"][0:5]
# df=df.rename(columns = {'PONo':'PO_Number_WF'})
# df["PO_Number_WF"] = df["PO_Number_WF"].astype(str)

# for a in range(len(df)):
# for j in range(len(df7)):
# #        print(df.loc[a,"PO_Number_WF"], df7['PO Number'][j])
#     if df.loc[a,"PO_Number_WF"] == df7['PO Number'][j]:
# #            print("True")
#         df.loc[a,"PO Document Date"] = df7['PO Document Date'][j]
#         df.loc[a,"SAP_PO_Val_Basic.(INR)"] = df7['SAP_PO_Val_Basic.(INR)'][j]
#     else:
# #            print("false")
#         df.loc[a,"FunctionSub"] = "NA"
#         df.loc[a,"Function"] = "NA"
# df.to_excel("E:\\Personal\\ACADGILD\\Project\\A_Df_Vs_Df7.xlsx")

# %%
#Date on a series
date = pd.Series(["2018/2/5","2018/3/5"])
date = pd.to_datetime(date,format = '%Y/%d/%m')
#date conversion in datfame
df = pd.read_csv("dob.csv")
print(df.head())

print(df.dtypes)
df['DOB'] = df['DOB'].apply(lambda x:pd.to_datetime(x,format = "%d/%m/%Y"))
#or
df['DOB'] = pd.to_datetime(df["DOB"],format = "%d/%m/%Y")
# import datetime as dt
# df['DOB_1'] = pd.to_datetime(df['DOB']+ dt.timedelta(days = 2))

# extracting yaer from date column
df['year'] = df['DOB'].dt.year
# extracting yaer from month column
df['month'] = df['DOB'].dt.month
df.head()


df["Date"] = df["Date"].astype(str).apply(lambda x: x[:11])
df["Day"] = df["Date"].astype(str).apply(lambda x: x[:2])
df["Month"] = df["Date"].astype(str).apply(lambda x: x[3:6])
df["YEAR"] = df["Date"].astype(str).apply(lambda x: x[-4:])
